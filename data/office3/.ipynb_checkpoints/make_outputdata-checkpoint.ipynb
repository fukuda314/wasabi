# %%
import os
import glob
import csv
import numpy as np
import pandas as pd

# %%
cd_path = os.getcwd()
output_path = os.path.join(cd_path,'data')

# %%
class output(object):
    
    def __init__(self, output_name, header, data):
        self.output_name = output_name
        self.header = header
        self.data = data
    
    def output_csv(self):
        with open (self.output_name, 'w') as fname:
            writer = csv.writer(fname)
            writer.writerow(self.header)
            for i in range(len(self.data)):
                writer.writerow(self.data[i])

# %%
office_name = 'office3_'
#header = ['x','y','z','num_droplets','volume','RoI']
#header = ['case_name','RoI']
#header = ['case_name','num_nozero', 'RoI']
header = ['case_name','diffusivity', 'RoI']

# %%
dir_list = glob.glob(output_path+'/*'+'/BoxCount_*')
num_dir = len(dir_list)
for j in range(int(num_dir/5)):
    df = {} 
    sum_data = np.zeros((3300, 5),dtype=np.float32)
    ave_data = np.zeros((3300, 5),dtype=np.float32)
    
    for i in range(5):
        fname = dir_list[i+5*j]
        #print(fname)
        df[i] = pd.read_csv(fname)
        df[i] = df[i].drop(df[i].columns[5], axis = 1)
        df[i] = df[i].to_numpy()
        sum_data += df[i]
        #print(df[i])

    ave_data = sum_data/ 5
    #print(ave_data)
    RoI = 1 - (np.exp(-ave_data[:,4] * 1e7 / (900/60)))
    RoI = RoI[:, np.newaxis]
    output_data = np.concatenate([ave_data,RoI], axis=1)
    output_data[:,:4] = np.around(output_data[:,:4], decimals=8)
    os.chdir(os.path.dirname(fname))
    out = output(output_name='BoxCount.csv', header=header, data=output_data)
    out.output_csv()

# %%
def remove_any_zero_row(df, selected_column):
    """"0の行を削除"""
    df = df.copy()
    num_index = df.shape[0]
    row_diff = 0
    for row in range(num_index):
        if (df.iloc[row - row_diff, selected_column] == 0):
            df.drop(row, axis=0, inplace=True)
            row_diff += 1
    return df

# %%
dir_list2 = glob.glob(output_path+'/*'+'/BoxCount.csv')
case_name_list = glob.glob(output_path+'/*')
num_dir2 = len(dir_list2)
output_ave_data = np.zeros((num_dir2, 2),dtype=np.float32)
for i in range(int(num_dir2)):
    case_name = os.path.basename(case_name_list[i])
    case_name_list[i] = office_name + case_name
    df_ave = pd.read_csv(dir_list2[i])
    num_data = df_ave.shape[0]
    ave_RoI = df_ave.mean(axis=0)
    print('chdir is', dir_list2[i])
    print(ave_RoI[5])
    df_ave_rm0 = remove_any_zero_row(df_ave, 5)
    num_nozero = df_ave_rm0.shape[0]
    ave_RoI_rm0 = df_ave_rm0.mean(axis=0)
    print(ave_RoI_rm0[5])
    diffusivity = num_nozero/num_data
    output_ave_data[i, 0] = diffusivity
    output_ave_data[i, 1] = ave_RoI_rm0[5]
    
case_name_list = np.array(case_name_list)
#output_ave_data = output_ave_data[:, np.newaxis]
case_name_list = case_name_list[:, np.newaxis]
output_ave_data = np.concatenate([case_name_list, output_ave_data], axis=1)

os.chdir(cd_path)
out = output(output_name = 'outputdata.csv', header = header, data = output_ave_data)
out.output_csv()
# Out:
# chdir is /home/enehen-master/laboratory/jupyter/ex_ML/ML/office3/data/960_164_aout/BoxCount.csv
# 0.03825372949574963
# 0.25815400273205275
# chdir is /home/enehen-master/laboratory/jupyter/ex_ML/ML/office3/data/960_82_bout/BoxCount.csv
# 0.03690612653210498
# 0.27616829377765634
# chdir is /home/enehen-master/laboratory/jupyter/ex_ML/ML/office3/data/960_246_bout/BoxCount.csv
# 0.03866601402477143
# 0.2675007259575382
# chdir is /home/enehen-master/laboratory/jupyter/ex_ML/ML/office3/data/660_164_bout/BoxCount.csv
# 0.03769750212640945
# 0.27644834892700265
# chdir is /home/enehen-master/laboratory/jupyter/ex_ML/ML/office3/data/0_164_bout/BoxCount.csv
# 0.040042859030401466
# 0.3295297625943263
# chdir is /home/enehen-master/laboratory/jupyter/ex_ML/ML/office3/data/0_82_aout/BoxCount.csv
# 0.03907904237207929
# 0.3145386337264919
# chdir is /home/enehen-master/laboratory/jupyter/ex_ML/ML/office3/data/960_82_aout/BoxCount.csv
# 0.043644819551632026
# 0.30449874105789776
# chdir is /home/enehen-master/laboratory/jupyter/ex_ML/ML/office3/data/0_246_bout/BoxCount.csv
# 0.04053701338519311
# 0.33526853175723625
# chdir is /home/enehen-master/laboratory/jupyter/ex_ML/ML/office3/data/0_0/BoxCount.csv
# 0.040212944859335464
# 0.3483010972068426
# chdir is /home/enehen-master/laboratory/jupyter/ex_ML/ML/office3/data/0_82_bout/BoxCount.csv
# 0.03904260622512474
# 0.3286750013849786
# chdir is /home/enehen-master/laboratory/jupyter/ex_ML/ML/office3/data/660_246_bout/BoxCount.csv
# 0.032972822731328344
# 0.235520162366631
# chdir is /home/enehen-master/laboratory/jupyter/ex_ML/ML/office3/data/0_246_aout/BoxCount.csv
# 0.038147935801566335
# 0.3348090110243854
# chdir is /home/enehen-master/laboratory/jupyter/ex_ML/ML/office3/data/660_164_aout/BoxCount.csv
# 0.0362366068860742
# 0.29746468339314636
# chdir is /home/enehen-master/laboratory/jupyter/ex_ML/ML/office3/data/360_82_aout/BoxCount.csv
# 0.04445362234329735
# 0.356926894727205
# chdir is /home/enehen-master/laboratory/jupyter/ex_ML/ML/office3/data/660_246_aout/BoxCount.csv
# 0.04117149076214227
# 0.3174437371847418
# chdir is /home/enehen-master/laboratory/jupyter/ex_ML/ML/office3/data/660_82_bout/BoxCount.csv
# 0.03674061484105323
# 0.269431175501057
# chdir is /home/enehen-master/laboratory/jupyter/ex_ML/ML/office3/data/360_164_aout/BoxCount.csv
# 0.042512720289753565
# 0.32932388956851355
# chdir is /home/enehen-master/laboratory/jupyter/ex_ML/ML/office3/data/360_0/BoxCount.csv
# 0.0419002391077066
# 0.33079136137663107
# chdir is /home/enehen-master/laboratory/jupyter/ex_ML/ML/office3/data/960_0/BoxCount.csv
# 0.03863050241788178
# 0.20627938184305808
# chdir is /home/enehen-master/laboratory/jupyter/ex_ML/ML/office3/data/660_82_aout/BoxCount.csv
# 0.03991366549996697
# 0.30071939760249083
# chdir is /home/enehen-master/laboratory/jupyter/ex_ML/ML/office3/data/0_164_aout/BoxCount.csv
# 0.04115729267559211
# 0.34039866122670165
# chdir is /home/enehen-master/laboratory/jupyter/ex_ML/ML/office3/data/360_246_bout/BoxCount.csv
# 0.04241464278632749
# 0.3380877323547843
# chdir is /home/enehen-master/laboratory/jupyter/ex_ML/ML/office3/data/960_246_aout/BoxCount.csv
# 0.041629467438023836
# 0.3115130216450762
# chdir is /home/enehen-master/laboratory/jupyter/ex_ML/ML/office3/data/960_164_bout/BoxCount.csv
# 0.03723162734712659
# 0.23537235679217958
# chdir is /home/enehen-master/laboratory/jupyter/ex_ML/ML/office3/data/360_246_aout/BoxCount.csv
# 0.039011755288395886
# 0.3234643026424785
# chdir is /home/enehen-master/laboratory/jupyter/ex_ML/ML/office3/data/360_164_bout/BoxCount.csv
# 0.04069197717175548
# 0.3115627022431394
# chdir is /home/enehen-master/laboratory/jupyter/ex_ML/ML/office3/data/660_0/BoxCount.csv
# 0.0341250097425093
# 0.2995014152932997
# chdir is /home/enehen-master/laboratory/jupyter/ex_ML/ML/office3/data/360_82_bout/BoxCount.csv
# 0.04204432620215576
# 0.33513593349544446
